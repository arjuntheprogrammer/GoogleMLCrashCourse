# %% [markdown]
# <a href="https://colab.research.google.com/github/arjuntheprogrammer/GoogleMLCrashCourse/blob/master/Intro_to_modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Intro to Modeling
#
#
# **Learning Objectives:**
# * Become familiar with pandas for handling small datasets
# * Use the tf.Estimator and Feature Column API to experiment with feature transformations
# * Use visualizations and run experiments to understand the value of feature transformations
#
# Please **make a copy** of this Colab notebook before starting this lab. To do so, choose **File**->**Save a copy in Drive**.

# %% [markdown]
# ## Setup
#
# Let's start by importing our dependencies.

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import math
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ## Pandas, a helpful data analysis library for in-memory dataset
#
# We use a package called [Pandas](http://pandas.pydata.org/) for reading in our data, exploring our data and doing some basic processing. It is really helpful for datasets that fit in memory! And it has some nice integrations, as you will see.
#
# First we set up some options to control how items are displayed and the maximum number of rows to show when displaying a table.  Feel free to change this setup to whatever you'd like.

# %%
# Set pandas output display to have one digit for decimal places and limit it to
# printing 15 rows.
pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_rows = 15

# %% [markdown]
# ### Load the dataset with pandas
# The car data set we will be using in this lab is provided as a comma separated file without a header row.  In order for each column to have a meaningful header name we must provide it.  We get the information about the columns from the [Automobile Data Set](https://archive.ics.uci.edu/ml/datasets/automobile).
#
# We will use the features of the car, to try to predict its price.

# %%
# Provide the names for the columns since the CSV file with the data does
# not have a header row.
feature_names = ['symboling', 'normalized-losses', 'make', 'fuel-type',
        'aspiration', 'num-doors', 'body-style', 'drive-wheels',
        'engine-location', 'wheel-base', 'length', 'width', 'height', 'weight',
        'engine-type', 'num-cylinders', 'engine-size', 'fuel-system', 'bore',
        'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
        'highway-mpg', 'price']


# Load in the data from a CSV file that is comma separated.
car_data = pd.read_csv('https://storage.googleapis.com/mledu-datasets/cars_data.csv',
                        sep=',', names=feature_names, header=None, encoding='latin-1')


# We'll then randomize the data, just to be sure not to get any pathological
# ordering effects that might harm the performance of Stochastic Gradient
# Descent.
car_data = car_data.reindex(np.random.permutation(car_data.index))

print("Data set loaded. Num examples: ", len(car_data))
# Out:
# Data set loaded. Num examples:  205

# %% [markdown]
# This is a really small dataset! Only 205 examples.
#
# For simplicity in this codelab, we do not split the data further into training and validation. But you MUST do this on real datasets, or else you will overfit to your single dataset.

# %% [markdown]
# ## Task 0: Use pandas to explore and prepare the data
#
# - Use Pandas to inspect the data and manually curate a list of numeric_feature_names and categorical_feature_names.
#
#
# Useful functions:
# - `type()` called on any Python object describes the type of the object
# - `dataframe[4:7]` pulls out rows 4, 5, 6 in a Pandas dataframe
# - `dataframe[['mycol1', 'mycol2']]` pulls out the two requested columns into a new Pandas dataframe
# - `dataframe['mycol1']` returns a Pandas series -- not a dataframe!
# - `dataframe.describe()` prints out statistics for each dataframe column

# %%
car_data[4:7]
# Out:
#      symboling normalized-losses        make  ... city-mpg highway-mpg price
# 155          0                91      toyota  ...       27          32  8778
# 78           2               161  mitsubishi  ...       31          38  6669
# 148          0                85      subaru  ...       23          29  8013
#
# [3 rows x 26 columns]

# %%
#@title Solution (to view code, from cell's menu, select Form -> Show Code)
numeric_feature_names = ['symboling', 'normalized-losses', 'wheel-base',
        'length', 'width', 'height', 'weight', 'engine-size', 'horsepower',
        'peak-rpm', 'city-mpg', 'highway-mpg', 'bore', 'stroke',
         'compression-ratio']

categorical_feature_names = list(set(feature_names) - set(numeric_feature_names) - set([LABEL]))

assert len(numeric_feature_names) == 15
assert len(categorical_feature_names) == 10

# %%
#@title Solution (to view code, from cell's menu, select Form -> Show Code)
numeric_feature_names = ['symboling', 'normalized-losses', 'wheel-base',
        'length', 'width', 'height', 'weight', 'engine-size', 'horsepower',
        'peak-rpm', 'city-mpg', 'highway-mpg', 'bore', 'stroke',
         'compression-ratio']

categorical_feature_names = list(set(feature_names) - set(numeric_feature_names) - set([LABEL]))

assert len(numeric_feature_names) == 15
assert len(categorical_feature_names) == 10

# %%
# Run to inspect numeric features.
car_data[numeric_feature_names]
# Out:
#      symboling  normalized-losses  wheel-base  ...  bore  stroke  compression-ratio
# 113          0               0.00      114.20  ...  3.46    2.19               8.40
# 165          1             168.00       94.50  ...  3.24    3.08               9.40
# 124          3               0.00       95.90  ...  3.59    3.86               7.00
# 11           0             192.00      101.20  ...  3.50    2.80               8.80
# 155          0              91.00       95.70  ...  3.05    3.03               9.00
# ..         ...                ...         ...  ...   ...     ...                ...
# 95           1             128.00       94.50  ...  3.15    3.29               9.40
# 90           1             128.00       94.50  ...  2.99    3.47              21.90
# 27           1             148.00       93.70  ...  3.03    3.39               7.60
# 126          3               0.00       89.50  ...  3.74    2.90               9.50
# 61           1             129.00       98.80  ...  3.39    3.39               8.60
#
# [205 rows x 15 columns]

# %%
# Run to inspect categorical features.
car_data[categorical_feature_names]
# Out:
#     num-cylinders aspiration body-style  ... fuel-type num-doors      make
# 113          four        std      wagon  ...       gas      four    peugot
# 165          four        std      sedan  ...       gas       two    toyota
# 124          four      turbo  hatchback  ...       gas       two  plymouth
# 11           four        std      sedan  ...       gas      four       bmw
# 155          four        std      wagon  ...       gas      four    toyota
# ..            ...        ...        ...  ...       ...       ...       ...
# 95           four        std  hatchback  ...       gas       two    nissan
# 90           four        std      sedan  ...    diesel       two    nissan
# 27           four      turbo      sedan  ...       gas         ?     dodge
# 126           six        std    hardtop  ...       gas       two   porsche
# 61           four        std  hatchback  ...       gas       two     mazda
#
# [205 rows x 10 columns]

# %%
# Coerce the numeric features to numbers. This is necessary because the model
# crashes because not all the values are numeric.
for feature_name in numeric_feature_names + [LABEL]:
  car_data[feature_name] = pd.to_numeric(car_data[feature_name], errors='coerce')

# Fill missing values with 0.
# Is this an OK thing to do? You may want to come back and revisit this decision later.
car_data.fillna(0, inplace=True)

# %% [markdown]
# ## Task 1: Make your best model with numeric features. No normalization allowed.
#
# Modify the model provided below to achieve the lowest eval loss. You may want to change various hyperparameters:
# - learning rate
# - choice of optimizer
# - hidden layer dimensions -- make sure your choice here makes sense given the number of training examples
# - batch size
# - num training steps
# - (anything else you can think of changing)
#
# Do not use the `normalizer_fn` arg on `numeric_column`.

# %%
#@title Possible solution
# Here is one possible solution:
# The only necessary change to fix the NaN training loss was the choice of optimizer.

# Changing other parameters could improve model quality, but take it with a
# grain of salt. The dataset is very small.

batch_size = 16

print(numeric_feature_names)
x_df = car_data[numeric_feature_names]
y_series = car_data['price']

train_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    y=y_series,
    batch_size=batch_size,
    num_epochs=None,
    shuffle=True)

eval_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    y=y_series,
    batch_size=batch_size,
    shuffle=False)

predict_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    batch_size=batch_size,
    shuffle=False)

# Feature columns allow the model to parse the data, perform common
# preprocessing, and automatically generate an input layer for the tf.Estimator.
model_feature_columns = [
    tf.feature_column.numeric_column(feature_name) for feature_name in numeric_feature_names
]
print('model_feature_columns', model_feature_columns)

est = tf.estimator.DNNRegressor(
    feature_columns=model_feature_columns,
    hidden_units=[64],
    optimizer=tf.train.AdagradOptimizer(learning_rate=0.01),
  )

# TRAIN
num_print_statements = 10
num_training_steps = 10000
for _ in range(num_print_statements):
  est.train(train_input_fn, steps=num_training_steps // num_print_statements)
  scores = est.evaluate(eval_input_fn)
  
  # The `scores` dictionary has several metrics automatically generated by the 
  # canned Estimator.
  # `average_loss` is the average loss for an individual example.
  # `loss` is the summed loss for the batch.
  # In addition to these scalar losses, you may find the visualization functions
  # in the next cell helpful for debugging model quality.
  print('scores', scores)
# Out:
# ['symboling', 'normalized-losses', 'wheel-base', 'length', 'width', 'height', 'weight', 'engine-size', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'bore', 'stroke', 'compression-ratio']
# model_feature_columns [NumericColumn(key='symboling', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='normalized-losses', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='wheel-base', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='length', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='width', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='height', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='weight', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='engine-size', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='horsepower', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='peak-rpm', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='city-mpg', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='highway-mpg', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='bore', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='stroke', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='compression-ratio', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpw8hhhlgx
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpw8hhhlgx', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ffaf839b7b8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpw8hhhlgx/model.ckpt.
# INFO:tensorflow
 'global_step': 9000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpw8hhhlgx/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9000 into /tmp/tmpw8hhhlgx/model.ckpt.
# INFO:tensorflow:loss = 900953860.0, step = 9000
# INFO:tensorflow:global_step/sec: 201.853
# INFO:tensorflow:loss = 288639260.0, step = 9100 (0.498 sec)
# INFO:tensorflow:global_step/sec: 257.77
# INFO:tensorflow:loss = 109345784.0, step = 9200 (0.388 sec)
# INFO:tensorflow:global_step/sec: 273.393
# INFO:tensorflow:loss = 473702600.0, step = 9300 (0.365 sec)
# INFO:tensorflow:global_step/sec: 256.817
# INFO:tensorflow:loss = 144466720.0, step = 9400 (0.389 sec)
# INFO:tensorflow:global_step/sec: 257.008
# INFO:tensorflow:loss = 258941200.0, step = 9500 (0.389 sec)
# INFO:tensorflow:global_step/sec: 268.061
# INFO:tensorflow:loss = 324479100.0, step = 9600 (0.373 sec)
# INFO:tensorflow:global_step/sec: 292.251
# INFO:tensorflow:loss = 434155700.0, step = 9700 (0.343 sec)
# INFO:tensorflow:global_step/sec: 246.263
# INFO:tensorflow:loss = 165904130.0, step = 9800 (0.405 sec)
# INFO:tensorflow:global_step/sec: 264.731
# INFO:tensorflow:loss = 140073020.0, step = 9900 (0.378 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/tmpw8hhhlgx/model.ckpt.
# INFO:tensorflow:Loss for final step: 228522640.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-31T16:25:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpw8hhhlgx/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-31-16:25:37
# INFO:tensorflow:Saving dict for global step 10000: average_loss = 23409586.0, global_step = 10000, label/mean = 12949.43, loss = 369151170.0, prediction/mean = 12998.459
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: /tmp/tmpw8hhhlgx/model.ckpt-10000
# scores {'average_loss': 23409586.0, 'label/mean': 12949.43, 'loss': 369151170.0, 'prediction/mean': 12998.459, 'global_step': 10000}

# %% [markdown]
# ### Visualize your model's predictions
#
# After you have a trained model, it may be helpful to understand how your model's inference differs from the actual data.
#
# This helper function `scatter_plot_inference` does that for you. Real data is in grey. Your model's predictions are in orange.

# %%
from matplotlib import pyplot as plt


def scatter_plot_inference_grid(est, x_df, feature_names):
  """Plots the predictions of the model against each feature.
  
  Args:
    est: The trained tf.Estimator.
    x_df: The pandas dataframe with the input data (used to create
      predict_input_fn).
    feature_names: An iterable of string feature names to plot.
  """
  def scatter_plot_inference(axis,
                             x_axis_feature_name,
                             y_axis_feature_name,
                             predictions):
    """Generate one subplot."""
    # Plot the real data in grey.
    y_axis_feature_name = 'price'
    axis.set_ylabel(y_axis_feature_name)
    axis.set_xlabel(x_axis_feature_name)
    axis.scatter(car_data[x_axis_feature_name],
                 car_data[y_axis_feature_name],
                 c='grey')

    # Plot the predicted data in orange.
    axis.scatter(car_data[x_axis_feature_name], predictions, c='orange')

  predict_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    batch_size=batch_size,
    shuffle=False)

  predictions = [
    x['predictions'][0]
    for x in est.predict(predict_input_fn)
  ]
  
  num_cols = 3
  num_rows = int(math.ceil(len(feature_names)/float(num_cols)))
  f, axarr = plt.subplots(num_rows, num_cols)
  size = 4.5
  f.set_size_inches(num_cols*size, num_rows*size)
  
  for i, feature_name in enumerate(numeric_feature_names):
    axis = axarr[int(i/num_cols), i%num_cols]
    scatter_plot_inference(axis, feature_name, 'price', predictions)
  plt.show()

scatter_plot_inference_grid(est, x_df, numeric_feature_names)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpw8hhhlgx/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# ## Task 2: Take your best numeric model from earlier. Add normalization.
#
# ### Add normalization to your best numeric model from earlier
#
# - You decide what type of normalization to add, and for which features
# - You will need to use the `normalizer_fn` arg on [`numeric_column`](https://g3doc.corp.google.com/learning/brain/public/g3doc/api_docs/python/tf/feature_column/numeric_column.md?cl=head)
#     - An example of a silly normalizer_fn that shifts inputs down by 1, and then negates the value:
#
#          normalizer_fn = lambda x: tf.neg(tf.subtract(x, 1))
#
# - You may find these pandas functions helpful:
#     - dataframe.mean()['your_feature_name']
#     - dataframe.std()['your_feature_name']
# - You will need to retune the hyperparameters from earlier.
#
#
# **Does normalization improve model quality on this dataset? Why or why not?**

# %%
# This 1D visualization of each numeric feature might inform your normalization
# decisions.
for feature_name in numeric_feature_names:
  car_data.hist(column=feature_name)

# %% [markdown]
# ###Train your model with numeric features + normalization

# %%
## Your code goes here

# %%
#@title Possible solution
# This does Z-score normalization since the distributions for most features looked
# roughly normally distributed.

# Z-score normalization subtracts the mean and divides by the standard deviation,
# to give a roughly standard normal distribution (mean = 0, std = 1) under a
# normal distribution assumption. Epsilon prevents divide by zero.

# With normalization, are you able to get the model working with
# GradientDescentOptimizer? Z-score normalization doesn't seem to be able to get
# SGD working. Maybe a different type of normalization would?

batch_size = 16

print(numeric_feature_names)
x_df = car_data[numeric_feature_names]
y_series = car_data['price']

train_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    y=y_series,
    batch_size=batch_size,
    num_epochs=None,
    shuffle=True)

eval_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    y=y_series,
    batch_size=batch_size,
    shuffle=False)

predict_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    batch_size=batch_size,
    shuffle=False)

# Epsilon prevents divide by zero.
epsilon = 0.000001
model_feature_columns = [
    tf.feature_column.numeric_column(feature_name,
                                     normalizer_fn=lambda val: (val - x_df.mean()[feature_name]) / (epsilon + x_df.std()[feature_name]))
    for feature_name in numeric_feature_names
]
print('model_feature_columns', model_feature_columns)

est = tf.estimator.DNNRegressor(
    feature_columns=model_feature_columns,
    hidden_units=[64],
    optimizer=tf.train.AdagradOptimizer(learning_rate=0.01),
  )

# TRAIN
num_print_statements = 10
num_training_steps = 10000
for _ in range(num_print_statements):
  est.train(train_input_fn, steps=num_training_steps // num_print_statements)
  scores = est.evaluate(eval_input_fn)
  
  # The `scores` dictionary has several metrics automatically generated by the 
  # canned Estimator.
  # `average_loss` is the average loss for an individual example.
  # `loss` is the summed loss for the batch.
  # In addition to these scalar losses, you may find the visualization functions
  # in the next cell helpful for debugging model quality.
  print('scores', scores)

scatter_plot_inference_grid(est, x_df, numeric_feature_names)
# Out:
# ['symboling', 'normalized-losses', 'wheel-base', 'length', 'width', 'height', 'weight', 'engine-size', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'bore', 'stroke', 'compression-ratio']
# model_feature_columns [NumericColumn(key='symboling', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf84bf048>), NumericColumn(key='normalized-losses', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf9fa8d90>), NumericColumn(key='wheel-base', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf9fa8f28>), NumericColumn(key='length', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf9fa8ea0>), NumericColumn(key='width', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf9fa8c80>), NumericColumn(key='height', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf9fa8b70>), NumericColumn(key='weight', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf98bdbf8>), NumericColumn(key='engine-size', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffb69cbad08>), NumericColumn(key='horsepower', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffb69e7d7b8>), NumericColumn(key='peak-rpm', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffafa146378>), NumericColumn(key='city-mpg', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf822aae8>), NumericColumn(key='highway-mpg', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf9eb6510>), NumericColumn(key='bore', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf7b410d0>), NumericColumn(key='stroke', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffb6a12b8c8>), NumericColumn(key='compression-ratio', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=<function <listcomp>.<lambda> at 0x7ffaf9d782f0>)]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpipglmoot
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpipglmoot', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ffaf9fc8978>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpipglmoot/model.ckpt.
# INFO:tensorflow:loss = 5944779000.0, step = 0
# INFO:tensorflow:global_step/sec: 196.073
# INFO:tensorflow:loss = 1639675000.0, step = 100 (0.510 sec)
# INFO:tensorflow:global_step/sec: 259.335
# INFO:tensorflow:loss = 2630270500.0, step = 200 (0.388 sec)
# INFO:tensorflow:global_step/sec: 239.809
# INFO:tensorflow:loss = 2527386600.0, step = 300 (0.416 sec)
# INFO:tensorflow:global_step/sec: 251.504
# INFO:tensorflow:loss = 1363290900.0, step = 400 (0.396 sec)
# INFO:tensorflow:global_step/sec: 231.188
# INFO:tensorflow:loss = 1018484860.0, step = 500 (0.435 sec)
# INFO:tensorflow:global_step/sec: 225.554
# INFO:tensorflow:loss = 246389420.0, step = 600 (0.443 sec)
# INFO:tensorflow:global_step/sec: 242.618
# INFO:tensorflow:loss = 237246560.0, step = 700 (0.413 sec)
# INFO:tensorflow:global_step/sec: 235.205
# INFO:tensorflow:loss = 827312000.0, step = 800 (0.425 sec)
# INFO:tensorflow:global_step/sec: 275.498
# INFO:tensorflow:loss = 1354023000.0, step = 900 (0.360 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpipglmoot/model.ckpt.
# INFO:tensorflow:Loss for final step: 573366000.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-31T16:26:20Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpipglmoot/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-31-16:26:20
# INFO:tensorflow:Saving dict for global step 1000: average_loss = 52299268.0, global_step = 1000, label/mean = 12949.43, loss = 824719200.0, prediction/mean = 13282.8955
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: /tmp/tmpipglmoot/model.ckpt-1000
# scores {'average_loss': 52299268.0, 'label/mean': 12949.43, 'loss': 824719200.0, 'prediction/mean': 13282.8955, 'global_step': 1000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpipglmoot/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpipglmoot/model.ckpt.
# INFO:tensorflow:loss = 221053090.0, step = 1000
# INFO:tensorflow:global_step/sec: 230.162
# INFO:tensorflow:loss = 1250970000.0, step = 1100 (0.436 sec)
# INFO:tensorflow:global_step/sec: 238.149
# INFO:tensorflow:loss = 842559200.0, step = 1200 (0.423 sec)
# INFO:tensorflow:global_step/sec: 254.509
# INFO:tensorflow:loss = 1139354500.0, step = 1300 (0.393 sec)
# INFO:tensorflow:global_step/sec: 251.254
# INFO:tensorflow:loss = 1246616000.0, step = 1400 (0.394 sec)
# INFO:tensorflow:global_step/sec: 251.158
# INFO:tensorflow:loss = 1102732900.0, step = 1500 (0.403 sec)
# INFO:tensorflow:global_step/sec: 249.755
 'global_step': 8000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpipglmoot/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 8000 into /tmp/tmpipglmoot/model.ckpt.
# INFO:tensorflow:loss = 913057150.0, step = 8000
# INFO:tensorflow:global_step/sec: 203.115
# INFO:tensorflow:loss = 773493900.0, step = 8100 (0.497 sec)
# INFO:tensorflow:global_step/sec: 245.828
# INFO:tensorflow:loss = 472557060.0, step = 8200 (0.404 sec)
# INFO:tensorflow:global_step/sec: 265.536
# INFO:tensorflow:loss = 369532400.0, step = 8300 (0.377 sec)
# INFO:tensorflow:global_step/sec: 237.602
# INFO:tensorflow:loss = 183481220.0, step = 8400 (0.418 sec)
# INFO:tensorflow:global_step/sec: 238.201
# INFO:tensorflow:loss = 839024100.0, step = 8500 (0.420 sec)
# INFO:tensorflow:global_step/sec: 238.248
# INFO:tensorflow:loss = 76074340.0, step = 8600 (0.422 sec)
# INFO:tensorflow:global_step/sec: 251.324
# INFO:tensorflow:loss = 578107100.0, step = 8700 (0.396 sec)
# INFO:tensorflow:global_step/sec: 266.161
# INFO:tensorflow:loss = 448718400.0, step = 8800 (0.378 sec)
# INFO:tensorflow:global_step/sec: 260.879
# INFO:tensorflow:loss = 916113400.0, step = 8900 (0.382 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into /tmp/tmpipglmoot/model.ckpt.
# INFO:tensorflow:Loss for final step: 372751420.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-31T16:27:06Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpipglmoot/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-31-16:27:07
# INFO:tensorflow:Saving dict for global step 9000: average_loss = 30947842.0, global_step = 9000, label/mean = 12949.43, loss = 488023680.0, prediction/mean = 13168.194
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: /tmp/tmpipglmoot/model.ckpt-9000
# scores {'average_loss': 30947842.0, 'label/mean': 12949.43, 'loss': 488023680.0, 'prediction/mean': 13168.194, 'global_step': 9000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpipglmoot/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9000 into /tmp/tmpipglmoot/model.ckpt.
# INFO:tensorflow:loss = 1115600000.0, step = 9000
# INFO:tensorflow:global_step/sec: 212.051
# INFO:tensorflow:loss = 124441360.0, step = 9100 (0.473 sec)
# INFO:tensorflow:global_step/sec: 246.767
# INFO:tensorflow:loss = 252163680.0, step = 9200 (0.404 sec)
# INFO:tensorflow:global_step/sec: 256.398
# INFO:tensorflow:loss = 620071200.0, step = 9300 (0.391 sec)
# INFO:tensorflow:global_step/sec: 249.706
# INFO:tensorflow:loss = 543179900.0, step = 9400 (0.400 sec)
# INFO:tensorflow:global_step/sec: 227.118
# INFO:tensorflow:loss = 179057420.0, step = 9500 (0.442 sec)
# INFO:tensorflow:global_step/sec: 238.655
# INFO:tensorflow:loss = 284033860.0, step = 9600 (0.416 sec)
# INFO:tensorflow:global_step/sec: 250.459
# INFO:tensorflow:loss = 631717100.0, step = 9700 (0.400 sec)
# INFO:tensorflow:global_step/sec: 263.051
# INFO:tensorflow:loss = 405750850.0, step = 9800 (0.383 sec)
# INFO:tensorflow:global_step/sec: 239.503
# INFO:tensorflow:loss = 279962300.0, step = 9900 (0.416 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/tmpipglmoot/model.ckpt.
# INFO:tensorflow:Loss for final step: 876677440.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-31T16:27:12Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpipglmoot/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-31-16:27:12
# INFO:tensorflow:Saving dict for global step 10000: average_loss = 29721642.0, global_step = 10000, label/mean = 12949.43, loss = 468687420.0, prediction/mean = 13190.158
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: /tmp/tmpipglmoot/model.ckpt-10000
# scores {'average_loss': 29721642.0, 'label/mean': 12949.43, 'loss': 468687420.0, 'prediction/mean': 13190.158, 'global_step': 10000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpipglmoot/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# ## Task 3: Make your best model using only categorical features
#
# - Look at the possible feature columns for categorical features. They begin with `categorical_column_with_` in go/tf-ops.
# - You may find `dataframe[categorical_feature_names].unique()` helpful.

# %%
#@title Possible solution
# We have the full list of values that each feature takes on, and the list is
# relatively small so we use categorical_column_with_vocabulary_list.

batch_size = 16

x_df = car_data[categorical_feature_names]
y_series = car_data['price']

train_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    y=y_series,
    batch_size=batch_size,
    num_epochs=None,
    shuffle=True)

eval_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    y=y_series,
    batch_size=batch_size,
    shuffle=False)

predict_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    batch_size=batch_size,
    shuffle=False)

model_feature_columns = [
    tf.feature_column.indicator_column(
        tf.feature_column.categorical_column_with_vocabulary_list(
            feature_name, vocabulary_list=car_data[feature_name].unique()))
    for feature_name in categorical_feature_names
]
print('model_feature_columns', model_feature_columns)

est = tf.estimator.DNNRegressor(
    feature_columns=model_feature_columns,
    hidden_units=[64],
    optimizer=tf.train.AdagradOptimizer(learning_rate=0.01),
  )

# TRAIN
num_print_statements = 10
num_training_steps = 10000
for _ in range(num_print_statements):
  est.train(train_input_fn, steps=num_training_steps // num_print_statements)
  scores = est.evaluate(eval_input_fn)
  
  # The `scores` dictionary has several metrics automatically generated by the
  # canned Estimator.
  # `average_loss` is the average loss for an individual example.
  # `loss` is the summed loss for the batch.
  # In addition to these scalar losses, you may find the visualization functions
  # in the next cell helpful for debugging model quality.
  print('scores', scores)
# Out:
# model_feature_columns [IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='num-cylinders', vocabulary_list=('four', 'six', 'three', 'five', 'twelve', 'eight', 'two'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='aspiration', vocabulary_list=('std', 'turbo'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='body-style', vocabulary_list=('wagon', 'sedan', 'hatchback', 'convertible', 'hardtop'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='engine-location', vocabulary_list=('front', 'rear'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='fuel-system', vocabulary_list=('mpfi', 'spdi', '2bbl', 'idi', '4bbl', '1bbl', 'mfi', 'spfi'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='drive-wheels', vocabulary_list=('rwd', '4wd', 'fwd'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='engine-type', vocabulary_list=
# INFO:tensorflow:loss = 1726722200.0, step = 8400 (0.499 sec)
# INFO:tensorflow:global_step/sec: 211.186
# INFO:tensorflow:loss = 4890990600.0, step = 8500 (0.471 sec)
# INFO:tensorflow:global_step/sec: 208.52
# INFO:tensorflow:loss = 3050968800.0, step = 8600 (0.480 sec)
# INFO:tensorflow:global_step/sec: 207.502
# INFO:tensorflow:loss = 2260896300.0, step = 8700 (0.484 sec)
# INFO:tensorflow:global_step/sec: 208.406
# INFO:tensorflow:loss = 2926405400.0, step = 8800 (0.478 sec)
# INFO:tensorflow:global_step/sec: 211.841
# INFO:tensorflow:loss = 5377251300.0, step = 8900 (0.474 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into /tmp/tmpstownv6q/model.ckpt.
# INFO:tensorflow:Loss for final step: 1846438100.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-31T16:28:35Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpstownv6q/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-31-16:28:35
# INFO:tensorflow:Saving dict for global step 9000: average_loss = 176013090.0, global_step = 9000, label/mean = 12949.43, loss = 2775591200.0, prediction/mean = 2445.4204
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: /tmp/tmpstownv6q/model.ckpt-9000
# scores {'average_loss': 176013090.0, 'label/mean': 12949.43, 'loss': 2775591200.0, 'prediction/mean': 2445.4204, 'global_step': 9000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpstownv6q/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9000 into /tmp/tmpstownv6q/model.ckpt.
# INFO:tensorflow:loss = 3072281600.0, step = 9000
# INFO:tensorflow:global_step/sec: 177.802
# INFO:tensorflow:loss = 2259192800.0, step = 9100 (0.563 sec)
# INFO:tensorflow:global_step/sec: 223.016
# INFO:tensorflow:loss = 2185269500.0, step = 9200 (0.447 sec)
# INFO:tensorflow:global_step/sec: 208.874
# INFO:tensorflow:loss = 2682836000.0, step = 9300 (0.481 sec)
# INFO:tensorflow:global_step/sec: 218.505
# INFO:tensorflow:loss = 2834346000.0, step = 9400 (0.456 sec)
# INFO:tensorflow:global_step/sec: 209.6
# INFO:tensorflow:loss = 4738166000.0, step = 9500 (0.478 sec)
# INFO:tensorflow:global_step/sec: 210.486
# INFO:tensorflow:loss = 4842959000.0, step = 9600 (0.475 sec)
# INFO:tensorflow:global_step/sec: 208.289
# INFO:tensorflow:loss = 3891684000.0, step = 9700 (0.480 sec)
# INFO:tensorflow:global_step/sec: 217.042
# INFO:tensorflow:loss = 4341513000.0, step = 9800 (0.462 sec)
# INFO:tensorflow:global_step/sec: 217.037
# INFO:tensorflow:loss = 3546349600.0, step = 9900 (0.458 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/tmpstownv6q/model.ckpt.
# INFO:tensorflow:Loss for final step: 2828677600.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-31T16:28:42Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpstownv6q/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-31-16:28:42
# INFO:tensorflow:Saving dict for global step 10000: average_loss = 170829630.0, global_step = 10000, label/mean = 12949.43, loss = 2693852000.0, prediction/mean = 2697.838
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: /tmp/tmpstownv6q/model.ckpt-10000
# scores {'average_loss': 170829630.0, 'label/mean': 12949.43, 'loss': 2693852000.0, 'prediction/mean': 2697.838, 'global_step': 10000}

# %% [markdown]
# ## Task 4: Using all the features, make the best model that you can make
#
# With all the features combined, your model should perform better than your earlier models using numerical and categorical models alone. Tune your model until that is the case.

# %%
#@title Possible solution
# This is a first pass at a model that uses all the features.
# Do you have any improvements?

batch_size = 16

x_df = car_data[numeric_feature_names + categorical_feature_names]
y_series = car_data['price']

train_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    y=y_series,
    batch_size=batch_size,
    num_epochs=None,
    shuffle=True)

eval_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    y=y_series,
    batch_size=batch_size,
    shuffle=False)

predict_input_fn = tf.estimator.inputs.pandas_input_fn(
    x=x_df,
    batch_size=batch_size,
    shuffle=False)

epsilon = 0.000001
model_feature_columns = [
    tf.feature_column.indicator_column(
        tf.feature_column.categorical_column_with_vocabulary_list(
            feature_name, vocabulary_list=car_data[feature_name].unique()))
    for feature_name in categorical_feature_names
] + [
    tf.feature_column.numeric_column(feature_name,
                                     normalizer_fn=lambda val: (val - x_df.mean()[feature_name]) / (epsilon + x_df.std()[feature_name]))
    for feature_name in numeric_feature_names
]


print('model_feature_columns', model_feature_columns)

est = tf.estimator.DNNRegressor(
    feature_columns=model_feature_columns,
    hidden_units=[64],
    optimizer=tf.train.AdagradOptimizer(learning_rate=0.01),
  )

# TRAIN
num_print_statements = 10
num_training_steps = 10000
for _ in range(num_print_statements):
  est.train(train_input_fn, steps=num_training_steps // num_print_statements)
  scores = est.evaluate(eval_input_fn)
  
  # The `scores` dictionary has several metrics automatically generated by the 
  # canned Estimator.
  # `average_loss` is the average loss for an individual example.
  # `loss` is the summed loss for the batch.
  # In addition to these scalar losses, you may find the visualization functions
  # in the next cell helpful for debugging model quality.
  print('scores', scores)
# Out:
# model_feature_columns [IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='num-cylinders', vocabulary_list=('four', 'six', 'three', 'five', 'twelve', 'eight', 'two'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='aspiration', vocabulary_list=('std', 'turbo'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='body-style', vocabulary_list=('wagon', 'sedan', 'hatchback', 'convertible', 'hardtop'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='engine-location', vocabulary_list=('front', 'rear'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='fuel-system', vocabulary_list=('mpfi', 'spdi', '2bbl', 'idi', '4bbl', '1bbl', 'mfi', 'spfi'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='drive-wheels', vocabulary_list=('rwd', '4wd', 'fwd'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='engine-type', vocabulary_list=('l', 'dohc', 'ohc', 'ohcf', 'ohcv', 'rotor', 'dohcv'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='fuel-type', vocabulary_list=('gas', 'diesel'), dtype=tf.string, default_value=-1, num_oov_buckets=0)), IndicatorColumn(categorical_column=VocabularyListCategoricalColumn(key='num-doors', vocabulary_list=
# INFO:tensorflow:loss = 992211460.0, step = 8400 (0.633 sec)
# INFO:tensorflow:global_step/sec: 151.413
# INFO:tensorflow:loss = 408484260.0, step = 8500 (0.661 sec)
# INFO:tensorflow:global_step/sec: 151.272
# INFO:tensorflow:loss = 84470460.0, step = 8600 (0.661 sec)
# INFO:tensorflow:global_step/sec: 156.852
# INFO:tensorflow:loss = 568010750.0, step = 8700 (0.634 sec)
# INFO:tensorflow:global_step/sec: 156.364
# INFO:tensorflow:loss = 207888880.0, step = 8800 (0.641 sec)
# INFO:tensorflow:global_step/sec: 153.986
# INFO:tensorflow:loss = 517745200.0, step = 8900 (0.648 sec)
# INFO:tensorflow:Saving checkpoints for 9000 into /tmp/tmp22cbxig2/model.ckpt.
# INFO:tensorflow:Loss for final step: 703339800.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-31T16:31:15Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp22cbxig2/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-31-16:31:15
# INFO:tensorflow:Saving dict for global step 9000: average_loss = 26301098.0, global_step = 9000, label/mean = 12949.43, loss = 414748100.0, prediction/mean = 13145.017
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: /tmp/tmp22cbxig2/model.ckpt-9000
# scores {'average_loss': 26301098.0, 'label/mean': 12949.43, 'loss': 414748100.0, 'prediction/mean': 13145.017, 'global_step': 9000}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp22cbxig2/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 9000 into /tmp/tmp22cbxig2/model.ckpt.
# INFO:tensorflow:loss = 604328600.0, step = 9000
# INFO:tensorflow:global_step/sec: 115.249
# INFO:tensorflow:loss = 360267600.0, step = 9100 (0.870 sec)
# INFO:tensorflow:global_step/sec: 157.364
# INFO:tensorflow:loss = 212187900.0, step = 9200 (0.634 sec)
# INFO:tensorflow:global_step/sec: 148.566
# INFO:tensorflow:loss = 774562200.0, step = 9300 (0.675 sec)
# INFO:tensorflow:global_step/sec: 145.835
# INFO:tensorflow:loss = 495983740.0, step = 9400 (0.686 sec)
# INFO:tensorflow:global_step/sec: 163.018
# INFO:tensorflow:loss = 159891840.0, step = 9500 (0.614 sec)
# INFO:tensorflow:global_step/sec: 155.252
# INFO:tensorflow:loss = 537124100.0, step = 9600 (0.644 sec)
# INFO:tensorflow:global_step/sec: 152.83
# INFO:tensorflow:loss = 257004380.0, step = 9700 (0.652 sec)
# INFO:tensorflow:global_step/sec: 148.368
# INFO:tensorflow:loss = 143305280.0, step = 9800 (0.677 sec)
# INFO:tensorflow:global_step/sec: 151.364
# INFO:tensorflow:loss = 264974480.0, step = 9900 (0.660 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into /tmp/tmp22cbxig2/model.ckpt.
# INFO:tensorflow:Loss for final step: 94343050.0.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-31T16:31:24Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmp22cbxig2/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-31-16:31:25
# INFO:tensorflow:Saving dict for global step 10000: average_loss = 25544010.0, global_step = 10000, label/mean = 12949.43, loss = 402809380.0, prediction/mean = 13106.984
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: /tmp/tmp22cbxig2/model.ckpt-10000
# scores {'average_loss': 25544010.0, 'label/mean': 12949.43, 'loss': 402809380.0, 'prediction/mean': 13106.984, 'global_step': 10000}

# %% [markdown]
# **Numeric features and No normalization**
# scores {'average_loss': 23409586.0, 'label/mean': 12949.43, 'loss': 369151170.0, 'prediction/mean': 12998.459, 'global_step': 10000}
#
# **Numeric features and with normalization**
# scores {'average_loss': 29721642.0, 'label/mean': 12949.43, 'loss': 468687420.0, 'prediction/mean': 13190.158, 'global_step': 10000}
#
# **Only categorical features**
# scores {'average_loss': 170829630.0, 'label/mean': 12949.43, 'loss': 2693852000.0, 'prediction/mean': 2697.838, 'global_step': 10000}
#
#  **Using all the features**
#  scores {'average_loss': 25544010.0, 'label/mean': 12949.43, 'loss': 402809380.0, 'prediction/mean': 13106.984, 'global_step': 10000}
